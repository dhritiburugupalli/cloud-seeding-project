# %% [markdown]
# <a href="https://colab.research.google.com/github/dhritiburugupalli/cloud-seeding-project/blob/main/notebooks/cloud_seeding_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

BASE = "/content/drive/MyDrive/cloud-seeding-project"
# Out:
# Mounted at /content/drive
